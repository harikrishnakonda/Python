# %%
import random


def get_user_choice():
    while True:

        user_choice = input("Choose Rock, Paper, Scissors: ").lower()
        if user_choice in ['rock', 'paper', 'scissors']:
          return user_choice
        else:
            print("Invalid choice. Please choose Rock, Paper, or Scissors.")

def get_computer_choice():
    return random.choice(['rock', 'paper', 'scissors'])

def determine_winner(user_choice, computer_choice):
    if computer_choice==user_choice:
        return 'It\s Draw!'
    elif user_choice== 'rock' and computer_choice== 'scissors':
        return 'You win!'

    elif computer_choice== 'rock' and user_choice== 'scissors':
        return 'You loose!'

    elif user_choice > computer_choice:
        return 'You win!'

    elif computer_choice > user_choice:
        return 'You loose!'

def game_image(user_choice, computer_choice):

      rock = '''
          _________
      ----'  _______)
            (________)
            (_________)
            (_______)
      ----__(_____)
      '''

      paper = '''

          _________
      ----'  _______)____
                  _______)_
                    _______)
                  ______)
      ----____________)

      '''

      scissors = '''

          _________
      ----'  _______)____
                  _______)__
                    ________)
              ______)
      ----_______)

      '''
      game_image = {'rock': rock,'paper': paper,'scissors': scissors}
      print(game_image[user_choice])
      print(game_image[computer_choice])
      return

def play_game():
    print("Welcome to Rock, Paper, Scissors!")

    while True:
        user_choice = get_user_choice()
        computer_choice = get_computer_choice()

        print(f"You chose: {user_choice}")


        print(f"Computer chose: {computer_choice}")
        # Print computer's image
        game_image(user_choice, computer_choice)

        result = determine_winner(user_choice, computer_choice)
        print(result)

        play_again = input("Do you want to play again? (yes/no): ").lower()
        if play_again != 'yes':
            print("Thanks for playing. Goodbye!")
            break

if __name__ == "__main__":
    play_game()
# Out:
# Welcome to Rock, Paper, Scissors!
# Choose Rock, Paper, Scissors: rock
# You chose: rock
# Computer chose: rock
#
#           _________
#       ----'  _______)
#             (________)
#             (_________)
#             (_______)
#       ----__(_____)
#
#
#           _________
#       ----'  _______)
#             (________)
#             (_________)
#             (_______)
#       ----__(_____)
#
# It\s Draw!
# Do you want to play again? (yes/no): no
# Thanks for playing. Goodbye!

# %%
import random


def get_user_choice():
    while True:

        user_choice = int(input("Enter you ckoice: Type 0  for Rock, 1 for Papeer, 2 for Scissors."))
        if user_choice in [0,1,2]:
          return user_choice
        else:
            print("Invalid choice. Please choose 0, 1 or 2.")

def get_computer_choice():
    return random.randint(0,2)

def determine_winner(user_choice, computer_choice):
    if computer_choice==user_choice:
        return 'It\s Draw!'
    elif user_choice == 0 and computer_choice == 2:
        return 'You win!'

    elif computer_choice == 0 and user_choice == 2:
        return 'You loose!'

    elif user_choice > computer_choice:
        return 'You win!'

    elif computer_choice > user_choice:
        return 'You loose!'

def game_image(user_choice, computer_choice):

      rock = '''
          _________
      ----'  _______)
            (________)
            (_________)
            (_______)
      ----__(_____)
      '''

      paper = '''

          _________
      ----'  _______)____
                  _______)_
                    _______)
                  ______)
      ----____________)

      '''

      scissors = '''

          _________
      ----'  _______)____
                  _______)__
                    ________)
              ______)
      ----_______)

      '''
      game_image = {0 : rock, 1 : paper, 2 : scissors}
      print(game_image[user_choice])
      print(game_image[computer_choice])
      return

def play_game():
    print("Welcome to Rock, Paper, Scissors Game!")

    while True:
        user_choice = get_user_choice()
        computer_choice = get_computer_choice()

        print(f"You chose: {user_choice}")

        print(f"Computer chose: {computer_choice}")

        game_image(user_choice, computer_choice)

        result = determine_winner(user_choice, computer_choice)
        print(result)

        play_again = input("Do you want to play again? (yes/no): ").lower()
        if play_again != 'yes':
            print("Thanks for playing. Goodbye!")
            break

if __name__ == "__main__":
    play_game()
# Out:
# Welcome to Rock, Paper, Scissors Game!
# Enter you ckoice: Type 0  for Rock, 1 for Papeer, 2 for Scissors.1
# You chose: 1
# Computer chose: 2
#
#
#           _________
#       ----'  _______)____
#                   _______)_
#                     _______)
#                   ______)
#       ----____________)
#
#
#
#
#           _________
#       ----'  _______)____
#                   _______)__
#                     ________)
#               ______)
#       ----_______)
#
#
# You loose!
# Do you want to play again? (yes/no): no
# Thanks for playing. Goodbye!

# %%
# Rock Paper Scissors Game..........
import random
print("Welcome to Rock Paper Scissors!")

rock = '''
     _________
----'  _______)
      (________)
      (_________)
      (_______)
----__(_____)
'''

paper = '''

     _________
----'  _______)____
             ______)_
              _______)
             ______)
----____________)

'''

scissors = '''

     _________
----'  _______)____
             _______)_
              ________)
        ______)
----_______)

'''

game_image = [rock,paper,scissors]

user_choice=int(input("enter you ckoice: Type 0  for Rock, 1 for Papeer, 2 for Scissors."))
if user_choice >=3 or user_choice < 0:
  print("You loose")
else:
  print(game_image[user_choice])
  computer_choice=random.randint(0,2)
  print("Computer chose: ")
  print(computer_choice)
  print(game_image[computer_choice])
  if computer_choice==user_choice:
    print("It's Draw.")
  elif user_choice==0 and computer_choice==2:
    print("You win")

  elif computer_choice==0 and user_choice==2:
    print("You loose")

  elif user_choice > computer_choice:
    print("You win")

  elif computer_choice > user_choice:
    print("You loose")
# Out:
# Welcome to Rock Paper Scissors!
# enter you ckoice: Type 0  for Rock, 1 for Papeer, 2 for Scissors.0
#
#      _________
# ----'  _______)
#       (________)
#       (_________)
#       (_______)
# ----__(_____)
#
# Computer chose:
# 1
#
#
#      _________
# ----'  _______)____
#              ______)_
#               _______)
#              ______)
# ----____________)
#
#
# You loose
